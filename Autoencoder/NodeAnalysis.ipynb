# %%
import pandas as pd

# %%
import os
os.chdir('/Users/caitdreisbach/Dropbox (Personal)/Autoencoder')

# %%
adage = pd.read_table('adage_gene_weights.tsv')  # Read a tsv into a DataFrame

adage.head(6)                           # Check the first 6 rows
# Out:
#    encodings   Tspan12     Tshz1    Fnbp1l    Cldn12    Sema3c      Jam2  \
# 0          1  0.006738  0.020858  0.009741 -0.013975  0.004567  0.011975
# 1          2  0.007696  0.024817  0.032824  0.023349 -0.012209 -0.013329
# 2          3 -0.008525 -0.019744  0.020625  0.021592  0.009652 -0.010031
# 3          4  0.003855  0.003763  0.007775  0.009056  0.017095  0.023641
# 4          5  0.000436 -0.009614  0.009800  0.013668  0.024496 -0.010258
# 5          6 -0.017850 -0.015738 -0.008363 -0.011995  0.001778  0.010815
#
#    BC005764    Klhl13  Tnfaip8l3    ...        Phka2     Cdkl5     Rbbp7  \
# 0 -0.011997  0.000441   0.009375    ...    -0.013396  0.010242  0.000042
# 1  0.009075 -0.002811  -0.016204    ...     0.006568  0.031386  0.013979
# 2  0.025176 -0.011526  -0.022447    ...    -0.009825  0.012737 -0.001759
# 3  0.020024 -0.000697  -0.018946    ...     0.008386  0.025788  0.033731
# 4  0.003625  0.012724  -0.019000    ...     0.023747  0.009102  0.007582
# ...

# %%
adage.describe()
# Out:
#         encodings     Tspan12       Tshz1      Fnbp1l      Cldn12      Sema3c  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    50.500000    0.000682    0.000552    0.002437    0.002686    0.003176
# std     29.011492    0.016026    0.015984    0.015655    0.014149    0.015115
# min      1.000000   -0.025027   -0.024485   -0.023019   -0.023640   -0.025352
# 25%     25.750000   -0.015235   -0.012654   -0.010565   -0.006751   -0.010281
# 50%     50.500000    0.002392   -0.002944    0.000854    0.003286    0.004386
# 75%     75.250000    0.015017    0.013346    0.013240    0.013435    0.015420
# max    100.000000    0.027512    0.038248    0.043098    0.029038    0.030981
#
#              Jam2    BC005764      Klhl13   Tnfaip8l3     ...           Phka2  \
# count  100.000000  100.000000  100.000000  100.000000     ...      100.000000
# mean     0.001394    0.001364   -0.000764   -0.000263     ...        0.001126
# ...

# %%
adage.set_index('encodings')
# Out:
#             Tspan12     Tshz1    Fnbp1l    Cldn12    Sema3c      Jam2  \
# encodings
# 1          0.006738  0.020858  0.009741 -0.013975  0.004567  0.011975
# 2          0.007696  0.024817  0.032824  0.023349 -0.012209 -0.013329
# 3         -0.008525 -0.019744  0.020625  0.021592  0.009652 -0.010031
# 4          0.003855  0.003763  0.007775  0.009056  0.017095  0.023641
# 5          0.000436 -0.009614  0.009800  0.013668  0.024496 -0.010258
# 6         -0.017850 -0.015738 -0.008363 -0.011995  0.001778  0.010815
# 7          0.017970  0.021713  0.023658 -0.016654  0.012786 -0.012860
# 8         -0.020658 -0.009020 -0.010713  0.000565 -0.019419 -0.019120
# 9         -0.016907  0.012252 -0.002899  0.015907  0.000743  0.020966
# 10         0.018988 -0.006279  0.028178  0.029038 -0.009497  0.010846
# 11         0.012168  0.020811 -0.011793 -0.020510 -0.015956  0.017838
# 12        -0.022434 -0.017304  0.014451 -0.004384  0.023693  0.022483
# ...

# %%
adage.idxmax(axis=0) #returns the index of the first maximum value
# Out:
# encodings         99
# Tspan12           57
# Tshz1             72
# Fnbp1l            72
# Cldn12             9
# Sema3c            77
# Jam2              83
# BC005764          46
# Klhl13            76
# Tnfaip8l3          8
# Atp1b2            78
# Prkar2b           77
# Necab1            78
# Nr2f2             81
# Stmn1.rs1         78
# Shisa9            11
# Sub1              72
# Dpysl5            60
# Cxcl14            72
# Ptprf             83
# Cers5             83
# Nacc2              9
# Cntnap2           68
# Rit2              27
# Scg2              72
# B3galnt1          68
# Gm9846            72
# Fam19a2           93
# Samd4             20
# Stmn1             72
#                   ..
# Nxt2              93
# Gm5643_loc1       72
# Lrch2             73
# Tmem29            97
# Maged2            72
# Tsr2              81
# Wnk3              27
# Fam120c           83
# Phf8              21
# Huwe1             72
# Hsd17b10          27
# Smc1a             40
# ...

# %%
maxexp = adage.max(axis=0)

# %%
#across full dataset
maxexp.sort_values(ascending=False) 

#Top 10 genes across all nodes
#Malat1              0.359900
#Calm1               0.207222
#Hsp90ab1            0.203503
#Tmsb4x              0.202427
#Plp1                0.198416
#Actb                0.197244
#Fth1                0.193868
#Ppia                0.189908
#Hsp90aa1            0.179386
#Lars2               0.178435
# Out:
# encodings         100.000000
# Malat1              0.359900
# Calm1               0.207222
# Hsp90ab1            0.203503
# Tmsb4x              0.202427
# Plp1                0.198416
# Actb                0.197244
# Fth1                0.193868
# Ppia                0.189908
# Hsp90aa1            0.179386
# Lars2               0.178435
# Itm2b               0.175152
# Rps29               0.168305
# Eef1a1              0.165440
# Calm2               0.165355
# H3f3b               0.163249
# Cox8a               0.160996
# Rplp1               0.154530
# App                 0.152440
# Cd81                0.150158
# Rps3                0.150075
# Actg1               0.148838
# Rpl35               0.147077
# Sparcl1             0.146369
# Serinc1             0.145726
# Son                 0.144934
# Ptn                 0.144858
# Cst3                0.144521
# Cox7c               0.144097
# Syt11               0.143059
#                      ...
# Sap18               0.024455
# ...
